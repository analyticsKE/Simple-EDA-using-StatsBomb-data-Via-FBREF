# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
players = pd.read_csv('F:/Data Analysis/Players Big 5/Players.csv')

# %%
players
# Out:
#                           Player   Nation   Pos          Squad  \
# 0            Max Aarons\774cf58b  eng ENG    DF   Norwich City
# 1      Yunis Abdelhamid\32c2d95f   ma MAR    DF          Reims
# 2     Salis Abdul Samed\82464ce3   gh GHA    MF  Clermont Foot
# 3       Laurent Abergel\31626657   fr FRA    MF        Lorient
# 4           Charles Abi\469d3d84   fr FRA    FW  Saint-Étienne
# ...                          ...      ...   ...            ...
# 2490   Martín Zubimendi\3ee0dd59   es ESP    MF  Real Sociedad
# 2491   Szymon Żurkowski\4e1d5e59   pl POL    MF         Empoli
# 2492    Martin Ødegaard\79300479   no NOR    MF        Arsenal
# 2493        Milan Đurić\405f6586   ba BIH    FW    Salernitana
# 2494      Filip Đuričić\eccbe56a   rs SRB  MFFW       Sassuolo
#
#                     Comp     Age    Born  MP  Starts   Min  ...  G+A-PK_90  \
# 0     eng Premier League  22-003  2000.0  18      18  1620  ...       0.06
# ...

# %%
players.dtypes
# Out:
# Player         object
# Nation         object
# Pos            object
# Squad          object
# Comp           object
# Age            object
# Born          float64
# MP              int64
# Starts          int64
# Min             int64
# 90s           float64
# Gls             int64
# Ast             int64
# G-PK            int64
# PK              int64
# PKatt           int64
# CrdY            int64
# CrdR            int64
# Gls_90        float64
# Ast_90        float64
# G+A_90        float64
# G-PK_90       float64
# G+A-PK_90     float64
# xG            float64
# npxG          float64
# xA            float64
# npxG+xA       float64
# xG_90         float64
# xA_90         float64
# xG+xA_90      float64
# npxG_90       float64
# npxG+xA_90    float64
# dtype: object

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      2495 non-null   object
#  1   Nation      2494 non-null   object
#  2   Pos         2495 non-null   object
#  3   Squad       2495 non-null   object
#  4   Comp        2495 non-null   object
#  5   Age         2494 non-null   object
#  6   Born        2494 non-null   float64
#  7   MP          2495 non-null   int64
#  8   Starts      2495 non-null   int64
#  9   Min         2495 non-null   int64
#  10  90s         2495 non-null   float64
#  11  Gls         2495 non-null   int64
#  12  Ast         2495 non-null   int64
#  13  G-PK        2495 non-null   int64
#  14  PK          2495 non-null   int64
#  15  PKatt       2495 non-null   int64
#  16  CrdY        2495 non-null   int64
#  17  CrdR        2495 non-null   int64
#  18  Gls_90      2495 non-null   float64
# ...

# %%
players.describe()
# Out:
#               Born           MP       Starts          Min          90s  \
# count  2494.000000  2495.000000  2495.000000  2495.000000  2495.000000
# mean   1995.065758    11.076553     8.094589   726.792786     8.075431
# std       4.457907     5.720795     6.097960   515.597307     5.728312
# min    1981.000000     1.000000     0.000000     1.000000     0.000000
# 25%    1992.000000     6.000000     2.000000   239.000000     2.650000
# 50%    1995.000000    12.000000     8.000000   688.000000     7.600000
# 75%    1998.000000    16.000000    13.000000  1163.000000    12.900000
# max    2005.000000    20.000000    20.000000  1800.000000    20.000000
#
#                Gls         Ast         G-PK           PK        PKatt  ...  \
# count  2495.000000  2495.00000  2495.000000  2495.000000  2495.000000  ...
# mean      1.014830     0.70982     0.918637     0.096192     0.116232  ...
# std       1.913575     1.23435     1.706923     0.477612     0.546290  ...
# ...

# %%
players[players['Born'] == 2005]
# Out:
#                         Player  Nation   Pos       Squad           Comp  \
# 307        Iker Bravo\db8c8860  es ESP    FW  Leverkusen  de Bundesliga
# 2102  Zidan Sertdemir\eec1f7f4  dk DEN  FWMF  Leverkusen  de Bundesliga
# 2247       Mathys Tel\829aa60c  fr FRA    FW      Rennes     fr Ligue 1
#
#          Age    Born  MP  Starts  Min  ...  G+A-PK_90   xG  npxG   xA  \
# 307   16-359  2005.0   1       0   12  ...        0.0  0.0   0.0  0.0
# 2102  16-337  2005.0   2       0    9  ...        0.0  0.0   0.0  0.0
# 2247  16-255  2005.0   3       0   36  ...        0.0  0.0   0.0  0.1
#
#       npxG+xA  xG_90  xA_90  xG+xA_90  npxG_90  npxG+xA_90
# 307       0.0    0.0   0.00      0.00      0.0        0.00
# 2102      0.0    0.0   0.00      0.00      0.0        0.00
# 2247      0.1    0.0   0.21      0.21      0.0        0.21
#
# [3 rows x 32 columns]

# %%
players[players['MP'] == 20]
# Out:
#                             Player   Nation   Pos            Squad  \
# 76        Felipe Anderson\9f1893b9   br BRA    FW            Lazio
# 232         Saïd Benrahma\5a04fd92   dz ALG  FWMF         West Ham
# 296          Jarrod Bowen\79c84d1c  eng ENG    FW         West Ham
# 364       Andrea Cambiaso\247ed022   it ITA    DF            Genoa
# 369          João Cancelo\bd6351cd   pt POR    DF  Manchester City
# 370      Antonio Candreva\356c9002   it ITA  MFFW        Sampdoria
# 483      Thibaut Courtois\1840e36d   be BEL    GK      Real Madrid
# 542       Grégoire Defrel\854ee61a   mq MTQ    FW         Sassuolo
# 576   Giovanni Di Lorenzo\230a2fac   it ITA    DF           Napoli
# 591            Rúben Dias\31c69ef1   pt POR    DF  Manchester City
# 669               Ederson\3bb7b8b4   br BRA    GK  Manchester City
# 680            Elif Elmas\cf007308   mk MKD  MFFW           Napoli
# 707      Łukasz Fabiański\9328b835   pl POL    GK         West Ham
# ...

# %%
players['Comp'].value_counts()
# Out:
# es La Liga            533
# it Serie A            518
# fr Ligue 1            508
# eng Premier League    482
# de Bundesliga         454
# Name: Comp, dtype: int64

# %%
players.sort_values(by='Squad')
# Out:
#                            Player   Nation   Pos   Squad                Comp  \
# 1529         Matt Miazga\9fc0f253   us USA    DF  Alavés          es La Liga
# 1284     Florian Lejeune\6eaed4eb   fr FRA    DF  Alavés          es La Liga
# 923        John Guidetti\99bebd12   se SWE  FWMF  Alavés          es La Liga
# 1333          Javi López\e9ada8cf   es ESP    DF  Alavés          es La Liga
# 2145      Antonio Sivera\9970da54   es ESP    GK  Alavés          es La Liga
# ...                           ...      ...   ...     ...                 ...
# 1651         Rúben Neves\44bfb6c5   pt POR    MF  Wolves  eng Premier League
# 450          Conor Coady\2928dca2  eng ENG    DF  Wolves  eng Premier League
# 2125         Fábio Silva\e7aa9d7c   pt POR  FWMF  Wolves  eng Premier League
# 841   Morgan Gibbs-White\32f60ed8  eng ENG  FWMF  Wolves  eng Premier League
# 562   Leander Dendoncker\5a7301ae   be BEL  MFFW  Wolves  eng Premier League
#
# ...

# %%
players['Nation'].value_counts()
# Out:
# es ESP     381
# fr FRA     337
# de GER     210
# it ITA     205
# eng ENG    195
#           ...
# pa PAN       1
# ir IRN       1
# gd GRN       1
# bg BUL       1
# nz NZL       1
# Name: Nation, Length: 101, dtype: int64

# %%
players['Comp'].value_counts()
# Out:
# es La Liga            533
# it Serie A            518
# fr Ligue 1            508
# eng Premier League    482
# de Bundesliga         454
# Name: Comp, dtype: int64

# %%
players['Gls'].value_counts()
# Out:
# 0     1512
# 1      429
# 2      228
# 3      103
# 4       70
# 5       58
# 6       30
# 7       23
# 8       14
# 9       11
# 10       5
# 11       3
# 16       3
# 12       2
# 15       1
# 13       1
# 14       1
# 19       1
# Name: Gls, dtype: int64

# %%
players[players['Gls'] >= 10]
# Out:
#                            Player  Nation   Pos          Squad  \
# 116           Iago Aspas\7dcf86f6  es ESP    FW     Celta Vigo
# 222    Wissam Ben Yedder\942b4f90  fr FRA    FW         Monaco
# 236        Karim Benzema\70d74ece  fr FRA    FW    Real Madrid
# 527       Jonathan David\ce50fd99  ca CAN    FW          Lille
# 946       Erling Haaland\1f44ac21  no NOR    FW       Dortmund
# 1055       Ciro Immobile\4431aed2  it ITA    FW          Lazio
# 1112              Joselu\6265208f  es ESP    FW         Alavés
# 1115          Diogo Jota\178ae8f8  pt POR    FW      Liverpool
# 1120              Juanmi\84399660  es ESP    FW          Betis
# 1125     Vinicius Júnior\7111d552  br BRA  FWMF    Real Madrid
# 1297  Robert Lewandowski\8d78e732  pl POL    FW  Bayern Munich
# 1449    Lautaro Martínez\f7036e1c  ar ARG    FW          Inter
# 1557     Anthony Modeste\34e4343c  fr FRA    FW           Köln
# 2016       Mohamed Salah\e342ad68  eg EGY    FW      Liverpool
# ...

# %%
len(players['Player'])
# Out:
# 2495

# %%
players['player_name'] = players['Player'][:2]
players
# Out:
#                           Player   Nation   Pos          Squad  \
# 0            Max Aarons\774cf58b  eng ENG    DF   Norwich City
# 1      Yunis Abdelhamid\32c2d95f   ma MAR    DF          Reims
# 2     Salis Abdul Samed\82464ce3   gh GHA    MF  Clermont Foot
# 3       Laurent Abergel\31626657   fr FRA    MF        Lorient
# 4           Charles Abi\469d3d84   fr FRA    FW  Saint-Étienne
# ...                          ...      ...   ...            ...
# 2490   Martín Zubimendi\3ee0dd59   es ESP    MF  Real Sociedad
# 2491   Szymon Żurkowski\4e1d5e59   pl POL    MF         Empoli
# 2492    Martin Ødegaard\79300479   no NOR    MF        Arsenal
# 2493        Milan Đurić\405f6586   ba BIH    FW    Salernitana
# 2494      Filip Đuričić\eccbe56a   rs SRB  MFFW       Sassuolo
#
#                     Comp     Age    Born  MP  Starts   Min  ...   xG  npxG  \
# 0     eng Premier League  22-003  2000.0  18      18  1620  ...  0.6   0.6
# ...

# %%
new = players['Player'].replace('\.',None)

# %%
players['Player'] = players['Player'].str.split('\\',expand=True)[0]

# %%
players['Comp'] = players['Comp'].str.split(' ',expand=True)[0]

# %%
players['Age'] = players['Age'].str.split('-',expand=True)[0]

# %%
players [players['xG'] == 16.7]
# Out:
#                   Player  Nation Pos          Squad Comp Age    Born  MP  \
# 1297  Robert Lewandowski  pl POL  FW  Bayern Munich   de  33  1988.0  17
#
#       Starts   Min  ...    xG  npxG   xA  npxG+xA  xG_90  xA_90  xG+xA_90  \
# 1297      17  1448  ...  16.7  14.4  3.8     18.2   1.04   0.24      1.28
#
#       npxG_90  npxG+xA_90  player_name
# 1297      0.9        1.13          NaN
#
# [1 rows x 33 columns]

# %%
players['Comp'].unique()
# Out:
# array(['eng', 'fr', 'de', 'it', 'es'], dtype=object)

# %%
prem = players[players['Comp'] == 'eng']
prem
# Out:
#                    Player   Nation   Pos            Squad Comp Age    Born  \
# 0              Max Aarons  eng ENG    DF     Norwich City  eng  22  2000.0
# 12              Che Adams  sct SCO    FW      Southampton  eng  25  1996.0
# 30        Rayan Aït Nouri   fr FRA    DF           Wolves  eng  20  2001.0
# 31        Kristoffer Ajer   no NOR    DF        Brentford  eng  23  1998.0
# 35             Nathan Aké   nl NED    DF  Manchester City  eng  26  1995.0
# ...                   ...      ...   ...              ...  ...  ..     ...
# 2460        Wilfried Zaha   ci CIV    FW   Crystal Palace  eng  29  1992.0
# 2482  Oleksandr Zinchenko   ua UKR    DF  Manchester City  eng  25  1996.0
# 2483         Hakim Ziyech   ma MAR  FWMF          Chelsea  eng  28  1993.0
# 2488           Kurt Zouma   fr FRA    DF         West Ham  eng  27  1994.0
# 2492      Martin Ødegaard   no NOR    MF          Arsenal  eng  23  1998.0
#
# ...

# %%
laliga = players[players['Comp'] == 'es']
bundesliga = players[players['Comp'] == 'de']
seriea = players[players['Comp'] == 'it']
ligue1 = players[players['Comp'] == 'fr']

# %%
laliga.describe()
# Out:
#               Born          MP      Starts          Min         90s  \
# count   532.000000  533.000000  533.000000   533.000000  533.000000
# mean   1994.387218   11.121951    7.883677   708.121951    7.866229
# std       4.536156    5.752912    6.009202   506.767307    5.630404
# min    1981.000000    1.000000    0.000000     1.000000    0.000000
# 25%    1991.000000    6.000000    2.000000   238.000000    2.600000
# 50%    1994.000000   12.000000    7.000000   643.000000    7.100000
# 75%    1998.000000   16.000000   13.000000  1102.000000   12.200000
# max    2004.000000   20.000000   20.000000  1800.000000   20.000000
#
#               Gls         Ast        G-PK          PK       PKatt  ...  \
# count  533.000000  533.000000  533.000000  533.000000  533.000000  ...
# mean     0.872420    0.624765    0.784240    0.088180    0.114447  ...
# std      1.766078    1.057513    1.580061    0.460581    0.527476  ...
# ...

# %%
players['Gls'].describe()
# Out:
# count    2495.000000
# mean        1.014830
# std         1.913575
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        19.000000
# Name: Gls, dtype: float64

# %%
players['Squad'].unique()
# Out:
# array(['Norwich City', 'Reims', 'Clermont Foot', 'Lorient',
#        'Saint-Étienne', 'Greuther Fürth', 'Rennes', 'Roma', 'Granada',
#        'Lazio', 'Eint Frankfurt', 'Sevilla', 'Southampton', 'RB Leipzig',
#        'Hoffenheim', 'Leverkusen', 'Bordeaux', 'Alavés', 'Athletic Club',
#        'Brest', 'Spezia', 'Barcelona', 'Monaco', 'Rayo Vallecano',
#        'Strasbourg', 'Celta Vigo', 'Torino', 'Wolves', 'Brentford',
#        'Dortmund', 'Cádiz', 'Manchester City', 'Betis', 'Real Madrid',
#        'Metz', 'Villarreal', 'Leicester City', 'Liverpool', 'Valencia',
#        'Getafe', 'Angers', 'Everton', 'Tottenham', 'Newcastle Utd',
#        'Chelsea', 'Cagliari', 'Brighton', 'Mallorca', 'Marseille',
#        'Venezia', 'Fiorentina', 'Crystal Palace', 'Köln', 'Arminia',
#        'Lille', 'Osasuna', 'Stuttgart', 'West Ham', 'Bochum', 'Lyon',
#        'Nantes', 'Aston Villa', 'Bologna', 'Wolfsburg', 'Udinese',
#        'Hertha BSC', 'Sampdoria', 'Empoli', 'Nice', 'Arsenal',
# ...

# %%
for index, row in players.iterrows():
    print(index, row['Squad'])
# Out:
# 0 Norwich City
# 1 Reims
# 2 Clermont Foot
# 3 Lorient
# 4 Saint-Étienne
# 5 Greuther Fürth
# 6 Rennes
# 7 Roma
# 8 Granada
# 9 Lazio
# 10 Eint Frankfurt
# 11 Sevilla
# 12 Southampton
# 13 RB Leipzig
# 14 Hoffenheim
# 15 Reims
# 16 Leverkusen
# 17 Bordeaux
# 18 Roma
# 19 Alavés
# 20 Athletic Club
# 21 Brest
# 22 Spezia
# 23 Rennes
# 24 Barcelona
# 25 Monaco
# 26 Rayo Vallecano
# 27 Strasbourg
# 28 Celta Vigo
# 29 Torino
# 30 Wolves
# 31 Brentford
# 32 Strasbourg
# 33 Dortmund
# 34 Cádiz
# 35 Manchester City
# 36 Barcelona
# 37 Monaco
# 38 Betis
# 39 Lazio
# 40 Hoffenheim
# 41 Real Madrid
# 42 Metz
# 43 Cádiz
# 44 Leverkusen
# 45 Barcelona
# 46 Lazio
# 47 Villarreal
# 48 Leicester City
# 49 Villarreal
# 50 Liverpool
# 51 Valencia
# 52 Cádiz
# 53 Getafe
# 54 Liverpool
# 55 Alavés
# 56 Angers
# 57 Liverpool
# 58 Everton
# 59 Clermont Foot
# 60 Tottenham
# 61 Newcastle Utd
# 62 Chelsea
# 63 Cagliari
# 64 Celta Vigo
# 65 Athletic Club
# 66 Brighton
# 67 Getafe
# 68 Leicester City
# ...

# %%
top_gls_xg_min = players.sort_values(by=['Gls','xG','Min'])
top_gls_xg_min.tail(10)
# Out:
#                   Player  Nation Pos          Squad Comp Age    Born  MP  \
# 1449    Lautaro Martínez  ar ARG  FW          Inter   it  24  1997.0  17
# 2132    Giovanni Simeone  ar ARG  FW  Hellas Verona   it  26  1995.0  18
# 527       Jonathan David  ca CAN  FW          Lille   fr  21  2000.0  19
# 946       Erling Haaland  no NOR  FW       Dortmund   de  21  2000.0  11
# 1055       Ciro Immobile  it ITA  FW          Lazio   it  31  1990.0  16
# 236        Karim Benzema  fr FRA  FW    Real Madrid   es  34  1987.0  19
# 2073       Patrik Schick  cz CZE  FW     Leverkusen   de  25  1996.0  14
# 2393      Dušan Vlahović  rs SRB  FW     Fiorentina   it  21  2000.0  19
# 2016       Mohamed Salah  eg EGY  FW      Liverpool  eng  29  1992.0  20
# 1297  Robert Lewandowski  pl POL  FW  Bayern Munich   de  33  1988.0  17
#
#       Starts   Min  ...    xG  npxG   xA  npxG+xA  xG_90  xA_90  xG+xA_90  \
# 1449      13  1067  ...  11.0   7.5  1.9      9.3   0.93   0.16      1.09
# ...

# %% [markdown]
# ### Expected Goals

# %%
players['xG'].value_counts()
# Out:
# 0.0    628
# 0.1    226
# 0.2    167
# 0.4    148
# 0.3    142
#       ...
# 8.9      1
# 9.6      1
# 7.7      1
# 7.4      1
# 9.3      1
# Name: xG, Length: 93, dtype: int64

# %%
players['xG'].value_counts().describe()
# Out:
# count     93.000000
# mean      26.827957
# std       74.123226
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%       15.000000
# max      628.000000
# Name: xG, dtype: float64

# %%
players[players['xG'] >= 7]
# Out:
#                   Player   Nation   Pos            Squad Comp Age    Born  MP  \
# 7          Tammy Abraham  eng ENG    FW             Roma   it  24  1997.0  19
# 88       Michail Antonio   jm JAM    FW         West Ham  eng  31  1990.0  19
# 103     Marko Arnautović   at AUT    FW          Bologna   it  32  1989.0  17
# 116           Iago Aspas   es ESP    FW       Celta Vigo   es  34  1987.0  18
# 126        Taiwo Awoniyi   ng NGA    FW     Union Berlin   de  24  1997.0  17
# 198         Mohamed Bayo   gn GUI    FW    Clermont Foot   fr  23  1998.0  17
# 236        Karim Benzema   fr FRA    FW      Real Madrid   es  34  1987.0  19
# 527       Jonathan David   ca CAN    FW            Lille   fr  21  2000.0  19
# 566        Memphis Depay   nl NED    FW        Barcelona   es  27  1994.0  15
# 884         Amine Gouiri   fr FRA  FWMF             Nice   fr  21  2000.0  19
# 946       Erling Haaland   no NOR    FW         Dortmund   de  21  2000.0  11
# ...

# %%
players[players['xG'] >= 9]
# Out:
#                   Player   Nation Pos          Squad Comp Age    Born  MP  \
# 7          Tammy Abraham  eng ENG  FW           Roma   it  24  1997.0  19
# 236        Karim Benzema   fr FRA  FW    Real Madrid   es  34  1987.0  19
# 527       Jonathan David   ca CAN  FW          Lille   fr  21  2000.0  19
# 1055       Ciro Immobile   it ITA  FW          Lazio   it  31  1990.0  16
# 1115          Diogo Jota   pt POR  FW      Liverpool  eng  25  1996.0  19
# 1297  Robert Lewandowski   pl POL  FW  Bayern Munich   de  33  1988.0  17
# 1408          Sadio Mané   sn SEN  FW      Liverpool  eng  29  1992.0  20
# 1449    Lautaro Martínez   ar ARG  FW          Inter   it  24  1997.0  17
# 1475       Kylian Mbappé   fr FRA  FW      Paris S-G   fr  23  1998.0  17
# 1557     Anthony Modeste   fr FRA  FW           Köln   de  33  1988.0  17
# 2016       Mohamed Salah   eg EGY  FW      Liverpool  eng  29  1992.0  20
# 2073       Patrik Schick   cz CZE  FW     Leverkusen   de  25  1996.0  14
# ...

# %% [markdown]
# ### Minutes played

# %%
players['Min'].describe()
# Out:
# count    2495.000000
# mean      726.792786
# std       515.597307
# min         1.000000
# 25%       239.000000
# 50%       688.000000
# 75%      1163.000000
# max      1800.000000
# Name: Min, dtype: float64

# %%
players[players['Min'] >= 1750].sort_values(by='Min',ascending=False)
# Out:
#                    Player   Nation   Pos            Squad Comp Age    Born  \
# 483      Thibaut Courtois   be BEL    GK      Real Madrid   es  29  1992.0
# 576   Giovanni Di Lorenzo   it ITA    DF           Napoli   it  28  1993.0
# 669               Ederson   br BRA    GK  Manchester City  eng  28  1993.0
# 707      Łukasz Fabiański   pl POL    GK         West Ham  eng  36  1985.0
# 1512        Edouard Mendy   sn SEN    GK          Chelsea  eng  29  1992.0
# 1769         Rui Patrício   pt POR    GK             Roma   it  33  1988.0
# 1987      Antonio Rüdiger   de GER    DF          Chelsea  eng  28  1993.0
# 2139     Salvatore Sirigu   it ITA    GK            Genoa   it  34  1987.0
# 2379    Guglielmo Vicario   it ITA    GK           Empoli   it  25  1996.0
# 1781           João Pedro   br BRA    FW         Cagliari   it  29  1992.0
# 1552      Tyrick Mitchell  eng ENG    DF   Crystal Palace  eng  22  1999.0
# ...

# %% [markdown]
# ### Data Transformation

# %%
all_teams = []
for x in players['Squad']:
    all_teams.extend(x)
teams = pd.unique(all_teams)

# %%
all_teams
# Out:
# ['N',
#  'o',
#  'r',
#  'w',
#  'i',
#  'c',
#  'h',
#  ' ',
#  'C',
#  'i',
#  't',
#  'y',
#  'R',
#  'e',
#  'i',
#  'm',
#  's',
#  'C',
#  'l',
#  'e',
#  'r',
#  'm',
#  'o',
#  'n',
#  't',
#  ' ',
#  'F',
#  'o',
#  'o',
#  't',
#  'L',
#  'o',
#  'r',
#  'i',
#  'e',
#  'n',
#  't',
#  'S',
#  'a',
#  'i',
#  'n',
#  't',
#  '-',
#  'É',
#  't',
#  'i',
#  'e',
#  'n',
#  'n',
#  'e',
#  'G',
#  'r',
#  'e',
#  'u',
#  't',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'F',
#  'ü',
#  'r',
#  't',
#  'h',
#  'R',
#  'e',
#  'n',
#  'n',
#  'e',
#  's',
#  'R',
#  'o',
#  'm',
#  'a',
#  'G',
#  'r',
#  'a',
#  'n',
#  'a',
#  'd',
#  'a',
#  'L',
#  'a',
#  'z',
#  'i',
#  'o',
#  'E',
#  'i',
#  'n',
#  't',
#  ' ',
#  'F',
#  'r',
#  'a',
#  'n',
#  'k',
#  'f',
#  'u',
#  'r',
#  't',
#  'S',
#  'e',
#  'v',
#  'i',
#  'l',
#  'l',
#  'a',
#  'S',
#  'o',
#  'u',
#  't',
#  'h',
#  'a',
#  'm',
#  'p',
#  't',
#  'o',
#  'n',
#  'R',
#  'B',
#  ' ',
#  'L',
#  'e',
#  'i',
#  'p',
# ...

# %% [markdown]
# # k-clustering

# %%
import mplsoccer, scikit

# %%
players

# %%
players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY',
#        'CrdR', 'Gls_90', 'Ast_90', 'G+A_90', 'G-PK_90', 'G+A-PK_90', 'xG',
#        'npxG', 'xA', 'npxG+xA', 'xG_90', 'xA_90', 'xG+xA_90', 'npxG_90',
#        'npxG+xA_90', 'player_name'],
#       dtype='object')

# %%
players = players[['Player','Squad','Comp','Pos','Age','90s','Gls']]
players
# Out:
#                  Player          Squad Comp   Pos Age   90s  Gls
# 0            Max Aarons   Norwich City  eng    DF  22  18.0    0
# 1      Yunis Abdelhamid          Reims   fr    DF  34  18.0    1
# 2     Salis Abdul Samed  Clermont Foot   fr    MF  21  15.7    0
# 3       Laurent Abergel        Lorient   fr    MF  28  17.6    0
# 4           Charles Abi  Saint-Étienne   fr    FW  21   0.5    0
# ...                 ...            ...  ...   ...  ..   ...  ...
# 2490   Martín Zubimendi  Real Sociedad   es    MF  22  14.2    0
# 2491   Szymon Żurkowski         Empoli   it    MF  24  10.3    3
# 2492    Martin Ødegaard        Arsenal  eng    MF  23  13.5    4
# 2493        Milan Đurić    Salernitana   it    FW  31   8.5    1
# 2494      Filip Đuričić       Sassuolo   it  MFFW  29   7.0    2
#
# [2495 rows x 7 columns]

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2495 non-null   object
#  1   Squad   2495 non-null   object
#  2   Comp    2495 non-null   object
#  3   Pos     2495 non-null   object
#  4   Age     2494 non-null   object
#  5   90s     2495 non-null   float64
#  6   Gls     2495 non-null   int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 136.6+ KB

# %%
players.describe()
# Out:
#                90s          Gls
# count  2495.000000  2495.000000
# mean      8.075431     1.014830
# std       5.728312     1.913575
# min       0.000000     0.000000
# 25%       2.650000     0.000000
# 50%       7.600000     0.000000
# 75%      12.900000     1.000000
# max      20.000000    19.000000

# %%
players = players[~players['Age'].isnull()]
#players = players[players[''].str.isnumeric()]
players[['Age']] = players[['Age']].astype(int)

# %%
players.describe()
# Out:
#                Age          90s          Gls
# count  2494.000000  2494.000000  2494.000000
# mean     25.967923     8.078589     1.015237
# std       4.449540     5.727288     1.913851
# min      16.000000     0.000000     0.000000
# 25%      23.000000     2.700000     0.000000
# 50%      26.000000     7.650000     0.000000
# 75%      29.000000    12.900000     1.000000
# max      40.000000    20.000000    19.000000

# %%
players.describe(include='object')
# Out:
#               Player      Squad  Comp   Pos
# count           2494       2494  2494  2494
# unique          2446         98     5    12
# top     Hélder Costa  Barcelona    es    DF
# freq               2         33   532   811

# %%
under23_chelsea = players[(players['Squad']=='Chelsea')&(players['Age']<=23)].reset_index(drop=True)

# %%
under23_chelsea
# Out:
#                Player    Squad Comp   Pos  Age   90s  Gls
# 0     Trevoh Chalobah  Chelsea  eng    DF   22  10.1    2
# 1         Kai Havertz  Chelsea  eng  FWMF   22  10.4    2
# 2  Callum Hudson-Odoi  Chelsea  eng  FWMF   21   8.5    1
# 3         Reece James  Chelsea  eng    DF   22  12.4    4
# 4         Mason Mount  Chelsea  eng  MFFW   22  13.9    7
# 5   Christian Pulisic  Chelsea  eng  FWMF   23   7.6    3
# 6         Malang Sarr  Chelsea  eng    DF   22   1.0    0

# %%
players['Age'] = players.loc[:,'A'] = players.Age.map(lambda x: x[1:-1]).astype(int)
players['y'] = df.loc[:,'y'] = df.y.map(lambda x: x[0:-1]).astype(float)
df['endX'] = df.loc[:,'endX'] = df.endX.map(lambda x: x[1:-1]).astype(float)
df['endY'] = df.loc[:,'endY'] = df.endY.map(lambda x: x[0:-1]).astype(float)
df = df.drop(['location','pass_end_location'],axis=1)

# %% [markdown]
# ### MOVING AVERAGE

# %%
players
# Out:
#                  Player          Squad Comp   Pos  Age   90s  Gls
# 0            Max Aarons   Norwich City  eng    DF   22  18.0    0
# 1      Yunis Abdelhamid          Reims   fr    DF   34  18.0    1
# 2     Salis Abdul Samed  Clermont Foot   fr    MF   21  15.7    0
# 3       Laurent Abergel        Lorient   fr    MF   28  17.6    0
# 4           Charles Abi  Saint-Étienne   fr    FW   21   0.5    0
# ...                 ...            ...  ...   ...  ...   ...  ...
# 2490   Martín Zubimendi  Real Sociedad   es    MF   22  14.2    0
# 2491   Szymon Żurkowski         Empoli   it    MF   24  10.3    3
# 2492    Martin Ødegaard        Arsenal  eng    MF   23  13.5    4
# 2493        Milan Đurić    Salernitana   it    FW   31   8.5    1
# 2494      Filip Đuričić       Sassuolo   it  MFFW   29   7.0    2
#
# [2494 rows x 7 columns]

# %%
under23_chelsea['Count'] = range(0,7)

# %%
under23_chelsea['AgeSMA'] = under23_chelsea['Age'].rolling(window=3).mean()

# %%
plt.plot(under23_chelsea['Count'],under23_chelsea['Age'],color='red')
